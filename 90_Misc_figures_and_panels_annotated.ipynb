# %% [markdown]
# # 90 Misc figures and panels
#
# **Origin:** `9_0_etc_figures.ipynb`
# **Annotated on:** 2025-10-13 06:45
#
# **High-level objective:**
# - Generate miscellaneous figures (summary panels, schematic elements) used across the manuscript.
#
# **Notes:**
# - These comments are language-agnostic and focus on intent, inputs, and outputs.
# - Adjust hard-coded paths if needed; prefer `/results_*` for derived artifacts.
#
# ---

# %% [markdown]
# **Step 1:** Visualization: figures/heatmaps/summary plots.

# %%
#Figure 2a
# schematics
# 

import numpy as np
import matplotlib.pyplot as plt

# Reproducibility
np.random.seed(0)

# Dummy data
genes = [f"G{i}" for i in range(1, 20)]  # 10 genes
effect_sizes = np.random.normal(0, 1, len(genes))

# Plot
fig, ax = plt.subplots(figsize=(3, 5))
im = ax.imshow(effect_sizes[:, None], aspect="auto", cmap=sns.diverging_palette(220, 20, as_cmap=True) )
ax.set_yticks(np.arange(len(genes)))
ax.set_yticklabels(genes)
ax.set_xticks([])
ax.set_title("Effect Sizes (β)")
plt.colorbar(im, ax=ax, fraction=0.08, pad=0.04, label="β")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Step 2:** Visualization: figures/heatmaps/summary plots.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dummy data
individuals = [f"Ind{i}" for i in range(1, 11)]  # 5 individuals

gene_expr = np.random.normal(0, 1, (len(genes), len(individuals)))

# Plot
fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(gene_expr, aspect="auto", cmap="coolwarm" )
ax.set_yticks(np.arange(len(genes)))
ax.set_yticklabels(genes)
ax.set_xticks(np.arange(len(individuals)))
ax.set_xticklabels(individuals, rotation= 45 , ha="right")
ax.set_title("Gene Expression (z-score, Genes × Individuals)")
plt.colorbar(im, ax=ax, fraction= 0.046,  pad=0.04, label="Expression (z-score)")

plt.tight_layout()
plt.show()
